# %% [markdown]
# Jour 1, Défi 1

# %%
# Initialisation des tableaux
colonne_1 = []
colonne_2 = []

# Initialisation des variables
total = 0

# Touver et supprimer la valeur la plus basse d'un tableau
def minrm( tab ) :
    valmin = min( tab )
    indirm = tab.index( valmin )
    tab.pop( indirm ) 
    return tab, valmin

# Lecture du fichier
with open('1_24', 'r') as fichier:
    for ligne in fichier:
        valeurs = ligne.split()
        colonne_1.append( int(valeurs[0]) )
        colonne_2.append( int(valeurs[1]) )

# Affichage des tableaux pour vérification
print("Colonne 1 :", colonne_1)
print("Colonne 2 :", colonne_2)

# Main
iteration = len(colonne_1)
for i in range(0, iteration) :
    cmin1 = 0
    cmin2 = 0
    colonne_1, cmin1 = minrm(colonne_1)
    colonne_2, cmin2 = minrm(colonne_2)
    total += abs( cmin1 - cmin2 )
    
# Résultat
print( total )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 16
#      13     return tab, valmin
#      15 # Lecture du fichier
# ---> 16 with open('1_24', 'r') as fichier:
#      17     for ligne in fichier:
#      18         valeurs = ligne.split()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '1_24'

# %% [markdown]
# Jour 1, Défi 2

# %%
# Initialisation des tableaux
colonne_1 = []
colonne_2 = []

# Initialisation des variables
total = 0

# Lecture du fichier
with open('1_24', 'r') as fichier:
    for ligne in fichier:
        valeurs = ligne.split()
        colonne_1.append( int(valeurs[0]) )
        colonne_2.append( int(valeurs[1]) )

# Affichage des tableaux pour vérification
print("Colonne 1 :", colonne_1)
print("Colonne 2 :", colonne_2)

# Main
for i in colonne_1 :
    total += i * colonne_2.count( i )
    
# Résultat
print( total )

# %% [markdown]
# Jour 2, Défi 1

# %%
# Initialisation des variables
data = []
total = 0

# Lecture du fichier
with open('2_24', 'r') as fichier:
    for ligne in fichier:
        valeurs = ligne.split()
        data.append(valeurs)

# Affichage des tableaux pour vérification
print (data)

# Fonction
def safe(tab) :
    var = 0
    if int(tab[0])>int(tab[1]) :
        croi = False
    elif int(tab[0])<int(tab[1]) :
        croi = True
    else :
        return 0
    
    for j in range ( 0, len(tab) - 1 ) :
        if (croi == True) :
            var = int(tab[j+1]) - int(tab[j])
        else :
            var = int(tab[j]) - int(tab[j+1])
        
        if var < 1 or var > 3 :
            return 0
    return 1
            
# Main
for i in data :
    total += safe(i)

# Résultat
print( total)

# %% [markdown]
# Jour 2, Défi 2

# %%
# Initialisation des variables
data = []
total = 0

# Lecture du fichier
with open('2_24', 'r') as fichier:
    for ligne in fichier:
        valeurs = ligne.split()
        data.append(valeurs)

# Affichage des tableaux pour vérification
print (data)

# Fonction
def safe(tab) :
    var = 0
    if int(tab[0])>int(tab[1]) :
        croi = False
    elif int(tab[0])<int(tab[1]) :
        croi = True
    else :
        return 0
    
    for j in range ( 0, len(tab) - 1 ) :
        if (croi == True) :
            var = int(tab[j+1]) - int(tab[j])
        else :
            var = int(tab[j]) - int(tab[j+1])
        
        if var < 1 or var > 3 :
            return 0
    return 1

def safe1(tab) : 
    # Separation du tableau en x sous tableau 
    subtabs = []
    for k in range (len(tab)) :
        subtab = tab[:k] + tab[k+1:]
        subtabs.append(subtab)
    
    for m in subtabs :
        if safe(m) == 1 :
            return 1
    return 0
            
# Main
for i in data :
    if safe(i) == 1 :  
        total += 1
    else :
        total += safe1(i)

# Résultat
print( total)

# %% [markdown]
# Jour 3, Défi 1

# %%
# Import
import re

# Variables
total = 0

# Fonction pour extraire les chaînes mul(x,y)
def extraire_mul():
    with open('3_24', 'r', encoding='utf-8') as fichier:
        contenu = fichier.read()
    
    # Expression régulière pour trouver mul(x,y)
    # \d+ correspond à un ou plusieurs chiffres
    pattern = r'mul\((\d+),(\d+)\)'
    resultats = re.findall(pattern, contenu)
    print (resultats)
    
    resultats = [(int(x), int(y)) for x, y in resultats]
    return resultats

# Main
resultats = extraire_mul()
for i in resultats :
    total += i[0] * i[1]
    
# Résultat
print(total)

# %% [markdown]
# Jour 3, Défi 2

# %%
# Import
import re

# Variables
total = 0

# Fonction pour extraire les chaînes mul(x,y)
def extraire_mul():
    with open('3_24', 'r', encoding='utf-8') as fichier:
        contenu = fichier.read()
    
    # Expression régulière pour trouver mul(x,y)
    # \d+ correspond à un ou plusieurs chiffres
    pattern = r"(mul|do|don't)\((\d+,\d+)?\)"
    tab = re.findall(pattern, contenu)
    return tab

def calcul_total(tab) :
    total_t = 0
    do = True
    for i in tab :
        if i[0] == 'do' :
            do = True
        elif i[0] == "don't" :
            do = False
        else :
            if do :
                mult = i[1].split(',')
                total_t += int(mult[0]) * int(mult[1])
    return total_t

# Main
resultats = extraire_mul()
print (resultats)
total = calcul_total(resultats)  

# Résultat
print(total)

# %% [markdown]
# Jour 4, Défi 1

# %%
# Initialisation des variables
data_tab = []
total = 0

# Lecture du fichier
def get_data():
    input = []
    with open('4_24', 'r') as fichier:
        for ligne in fichier :
            tab = []
            for char in ligne :
                tab.append(char)
            input.append(tab)
    return input

# Verifie si le mot passe dans le tableau
def distance(tab, y, x) :
    up_b = True if y - 3 >= 0 else False
    down_b = True if y + 3 <= len(tab) - 1 else False
    right_b = True if x + 3 <= len(tab) - 1 else False
    left_b = True if x - 3 >= 0 else False
    return up_b, right_b, down_b, left_b

# Cherche le nb d'itération du mot XMAS
def check_word(tab, y, x) :
    ite_xmas = 0
    up, right, down, left = distance(tab, y, x)
    
    if up :
        if tab[y-1][x] == 'M' and tab[y-2][x] == 'A' and tab[y-3][x] == 'S' :
            ite_xmas += 1
    if up and right :
        if tab[y-1][x+1] == 'M' and tab[y-2][x+2] == 'A' and tab[y-3][x+3] == 'S' :
            ite_xmas += 1
    if right :
        if tab[y][x+1] == 'M' and tab[y][x+2] == 'A' and tab[y][x+3] == 'S' :
            ite_xmas += 1
    if right and down :
        if tab[y+1][x+1] == 'M' and tab[y+2][x+2] == 'A' and tab[y+3][x+3] == 'S' :
            ite_xmas += 1
    if down :
        if tab[y+1][x] == 'M' and tab[y+2][x] == 'A' and tab[y+3][x] == 'S' :
            ite_xmas += 1
    if down and left :
        if tab[y+1][x-1] == 'M' and tab[y+2][x-2] == 'A' and tab[y+3][x-3] == 'S' :
            ite_xmas += 1
    if left :
        if tab[y][x-1] == 'M' and tab[y][x-2] == 'A' and tab[y][x-3] == 'S' :
            ite_xmas += 1
    if left and up :
        if tab[y-1][x-1] == 'M' and tab[y-2][x-2] == 'A' and tab[y-3][x-3] == 'S' :
            ite_xmas += 1
    
    return ite_xmas
                
# Main
data_tab = get_data()
print (data_tab)

for y in range (0, len(data_tab)) :
    for x in range( 0, len(data_tab[y]) ) :
        if data_tab[y][x] == 'X' :
            total += check_word(data_tab, y, x)
            
# Résultat
print(total)

# %% [markdown]
# Jour 4, Défi 2

# %%
# Initialisation des variables
data_tab = []
total = 0

# Lecture du fichier
def get_data():
    input = []
    with open('4_24', 'r') as fichier:
        for ligne in fichier :
            tab = []
            for char in ligne :
                tab.append(char)
            input.append(tab)
    return input

# Verifie si le mot passe dans le tableau
def distance(tab, y, x) :
    space_b = True if y - 1 >= 0 and y + 1 <= len(tab) - 1 and x - 1 >= 0 and x + 1 <= len(tab[y]) - 1 else False
    return space_b

# Cherche le nb d'itération du mot XMAS
def check_word(tab, y, x) :
    ite_xmas = 0
    space = distance(tab, y, x)
    
    if space :
        if tab[y-1][x-1] == 'M' and tab[y-1][x+1] == 'M' and tab[y+1][x+1] == 'S' and tab[y+1][x-1] == 'S':
            ite_xmas += 1
        elif tab[y-1][x-1] == 'S' and tab[y-1][x+1] == 'M' and tab[y+1][x+1] == 'M' and tab[y+1][x-1] == 'S':
            ite_xmas += 1
        elif tab[y-1][x-1] == 'S' and tab[y-1][x+1] == 'S' and tab[y+1][x+1] == 'M' and tab[y+1][x-1] == 'M':
            ite_xmas += 1
        elif tab[y-1][x-1] == 'M' and tab[y-1][x+1] == 'S' and tab[y+1][x+1] == 'S' and tab[y+1][x-1] == 'M':
            ite_xmas += 1
    
    return ite_xmas
                
# Main
data_tab = get_data()
print (data_tab)

for y in range (0, len(data_tab)) :
    for x in range( 0, len(data_tab[y]) ) :
        if data_tab[y][x] == 'A' :
            total += check_word(data_tab, y, x)
            
# Résultat
print(total)

# %% [markdown]
# Jour 5, Défi 1

# %%
# Initialisation des tableaux
rule_tab = []
data_tab = []
rule = []
verif = []
good = []

# Initialisation des variables
total = 0
debut_b = True

# Fonctions
def is_in(tab, val) :
    for j in range(0, len(tab)) :
        if val == tab[j][0] :
                return True, j
    return False, 0

def tri_rule(tab):
    tri = []
    for i in tab :
        in_b, ind = is_in(tri, i[0])
        if not in_b :
            x = [i[0], [i[1]]]
            tri.append(x)
        else :
            tri[ind][1].append(i[1])  
    return tri

def check(tab, val) :
    for i in range(0, len(tab)):
        if val == tab[i][0] :
            return tab[i][1]
    return []

def somme_mid(tab) :
    somme = 0
    for i in tab :
        x = int((len(i)-1)/2)
        somme += int(i[x])
    return somme

# Lecture du fichier
with open('5_24', 'r') as fichier:
    for ligne in fichier:
        if ligne == '\n':
            debut_b = False
        elif debut_b :
            rule_tab.append(ligne.strip().split('|'))
        else :
            data_tab.append(ligne.strip().split(','))

# Main
rule = tri_rule(rule_tab)

for i in data_tab :
    good_b = True
    for j in range (1, len(i)) :
        verif = check(rule, i[j])
        for k in range (0, j) :
            if i[k] in verif :
                good_b = False
    if good_b :
        good.append(i)
total = somme_mid(good)

# Résultat
print( total )
# Out:
# 4872

# %% [markdown]
# Jour 5, Défi 2

# %%
# Initialisation des tableaux
rule_tab = []
data_tab = []
rule = []
verif = []
good = []
good_2 = []
bad = []

# Initialisation des variables
total = 0
debut_b = True

# Fonctions
def is_in(tab, val) :
    for j in range(0, len(tab)) :
        if val == tab[j][0] :
                return True, j
    return False, 0

def tri_rule(tab):
    tri = []
    for i in tab :
        in_b, ind = is_in(tri, i[0])
        if not in_b :
            x = [i[0], [i[1]]]
            tri.append(x)
        else :
            tri[ind][1].append(i[1])  
    return tri

def check(tab, val) :
    for i in range(0, len(tab)):
        if val == tab[i][0] :
            return tab[i][1]
    return []

def somme_mid(tab) :
    somme = 0
    for i in tab :
        x = int((len(i)-1)/2)
        somme += int(i[x])
    return somme

def modif(tab, tab2) :
    for j in range (1, len(tab)) :
            verif = check(tab2, tab[j])
            for k in range (0, j) :
                if tab[k] in verif :
                    x = tab[j]
                    tab.pop(j)
                    tab = [x] + tab
                    return tab, True
    #print ('fin modif')
    return tab, False

# Lecture du fichier
with open('5_24', 'r') as fichier:
    for ligne in fichier:
        if ligne == '\n':
            debut_b = False
        elif debut_b :
            rule_tab.append(ligne.strip().split('|'))
        else :
            data_tab.append(ligne.strip().split(','))

# Main
rule = tri_rule(rule_tab)

for i in data_tab :
    good_b = True
    for j in range (1, len(i)) :
        verif = check(rule, i[j])
        for k in range (0, j) :
            if i[k] in verif :
                good_b = False
    if good_b :
        good.append(i)
    else :
        bad.append(i)

for i in range(0,len(bad)) :
    bad_g = True
    count = 0
    while bad_g :
        bad[i], bad_g = modif(bad[i], rule)
        count += 1
        if count >= 1000000 :
            bad_g = False
    #print(bad[i])



total = somme_mid(bad)

# Résultat
print( total )
# Out:
# 5564

# %% [markdown]
# Jour 6, Défi 1

# %%
# Variables
fichier_emp = 'input.txt'
data = []
dep_count = []
in_b = True
direction = ''


# Lecture du fichier
def get_data():
    input = []
    with open(fichier_emp, 'r') as fichier:
        for ligne in fichier :
            tab = []
            for char in ligne.strip() :
                tab.append(char)
            input.append(tab)
    return input

def trouver_pos_dir(tab) :
    for i, ligne in enumerate(tab):
        for j, val in enumerate(ligne):
            if val == '^' :
                return i, j, 'up'
            elif val == '>' :
                return i, j, 'right'
            elif val == 'v' :
                return i, j, 'down'
            elif val == '<' :
                return i, j, 'left'
            
def next_action(tab, i, j, dir) :
    if dir == "up" and i-1 >= 0:
        if tab[i-1][j] == '#' :
            tab[i][j] = '>'
            return tab, False, "right"
        else : 
            return tab, True, "up"
    elif dir == "right" and j+1 < len(tab[i]) :
        if tab[i][j+1] == '#' :
            tab[i][j] = 'v'
            return tab, False, "down"
        else : 
            return tab, True, "right"
    elif dir == "down" and i+1 < len(tab) :
        if tab[i+1][j] == '#' :
            tab[i][j] = '<'
            return tab, False, "left"
        else : 
            return tab, True, "down"
    elif dir == "left" and j-1 >= 0:
        if tab[i][j-1] == '#' :
            tab[i][j] = '^'
            return tab,False, "up"
        else : 
            return tab, True, "left"
    else :
        return tab, False, "end"
    
def avancer(tab, i , j, dir) :
    if dir == 'up' :
        tab[i][j] = '.'
        tab[i-1][j] = '^'
    elif dir == 'right' :
        tab[i][j] = '.'
        tab[i][j+1] = '>'
    elif dir == 'down' :
        tab[i][j] = '.'
        tab[i+1][j] = 'v'
    elif dir == 'left':
        tab[i][j] = '.'
        tab[i][j-1] = '<'
    return tab

def score_count(tab) :
    total = 0
    for ligne in tab:
        for val in ligne:
            total += val
    return total

# Main

data = get_data()
print(data)
dep_count = [[0 for _ in range(len(data[0]))] for _ in range(len(data))]
print (dep_count)
count = 0
while  direction != 'end':
    count +=1
    y, x, direction = trouver_pos_dir(data)
    dep_count[y][x] = 1
    data, avancer_b, direction = next_action(data, y, x, direction)
    if avancer_b :
        data = avancer(data, y, x, direction)
        
score = score_count(dep_count)

# Résultat 
print (score)
# Out:
# [['.', '.', '.', '.', '.', '.', '.', '.', '#', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '#', '.', '.', '.', '.', '.', '.', '#', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '#', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '#', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '#', '.', '.', '.', '.', '.', '.', '.', '.', '.', '#', '.', '#', '.', '#', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '#', '.', '.', '#', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.',
# ...

# %% [markdown]
# Jour 6, Défi 2

# %%
# Variables
fichier_emp = 'input.txt'
data = []
dep_count = []
in_b = True
direction = ''

ordre = []


# Lecture du fichier
def get_data():
    input = []
    with open(fichier_emp, 'r') as fichier:
        for ligne in fichier :
            tab = []
            for char in ligne.strip() :
                tab.append(char)
            input.append(tab)
    return input

def trouver_pos_dir(tab) :
    for i, ligne in enumerate(tab):
        for j, val in enumerate(ligne):
            if val == '^' :
                return i, j, 'up'
            elif val == '>' :
                return i, j, 'right'
            elif val == 'v' :
                return i, j, 'down'
            elif val == '<' :
                return i, j, 'left'
            
def next_action(tab, i, j, dir) :
    if dir == "up" and i-1 >= 0:
        if tab[i-1][j] == '#' :
            tab[i][j] = '>'
            return tab, False, "right"
        else : 
            return tab, True, "up"
    elif dir == "right" and j+1 < len(tab[i]) :
        if tab[i][j+1] == '#' :
            tab[i][j] = 'v'
            return tab, False, "down"
        else : 
            return tab, True, "right"
    elif dir == "down" and i+1 < len(tab) :
        if tab[i+1][j] == '#' :
            tab[i][j] = '<'
            return tab, False, "left"
        else : 
            return tab, True, "down"
    elif dir == "left" and j-1 >= 0:
        if tab[i][j-1] == '#' :
            tab[i][j] = '^'
            return tab,False, "up"
        else : 
            return tab, True, "left"
    else :
        return tab, False, "end"
    
def avancer(tab, i , j, dir) :
    if dir == 'up' :
        tab[i][j] = '.'
        tab[i-1][j] = '^'
    elif dir == 'right' :
        tab[i][j] = '.'
        tab[i][j+1] = '>'
    elif dir == 'down' :
        tab[i][j] = '.'
        tab[i+1][j] = 'v'
    elif dir == 'left':
        tab[i][j] = '.'
        tab[i][j-1] = '<'
    return tab

def score_count(tab) :
    total = 0
    for ligne in tab:
        for val in ligne:
            total += val
    return total

# Main

data = get_data()
print(data)
dep_count = [[0 for _ in range(len(data[0]))] for _ in range(len(data))]
print (dep_count)
count = 0
while  direction != 'end':
    count +=1
    y, x, direction = trouver_pos_dir(data)
    dep_count[y][x] = 1
    data, avancer_b, direction = next_action(data, y, x, direction)
    if avancer_b :
        data = avancer(data, y, x, direction)
        if [y,x] not in ordre :
            ordre.append([y,x])
        
score = score_count(dep_count)

#Suite du pb

ordre.pop(0)
ordre.append([121, 0])
# ordre.append([0, 101])
# ordre.append([9, 7])
print(ordre)
print(len(ordre), ordre[0])

nb_caisse = 0
for couple in ordre :
    modif_data = get_data()
    modif_data[couple[0]][couple[1]] = '#'

    direction = 'up'
    count = 0
    while  direction != 'end':
        count += 1
        y, x, direction = trouver_pos_dir(modif_data)
        modif_data, avancer_b, direction = next_action(modif_data, y, x, direction)
        if avancer_b :
            modif_data = avancer(modif_data, y, x, direction)
        if count > 10000 :
            print(couple)
            nb_caisse += 1
            direction = 'end'
            
# Résultat
print('score :',score,' nb caisse :', nb_caisse)
# Out:
# [['.', '.', '.', '.', '.', '.', '.', '.', '#', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '#', '.', '.', '.', '.', '.', '.', '#', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '#', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '#', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '#', '.', '.', '.', '.', '.', '.', '.', '.', '.', '#', '.', '#', '.', '#', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '#', '.', '.', '#', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.',
# ...
